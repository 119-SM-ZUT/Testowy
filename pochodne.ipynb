# %%
import sympy as sp
sp.init_printing()

# %%
x, y = sp.symbols('x y' , real=True)

# %%
x.is_real,y.is_integer
# Out:
# (True, None)

# %%
n1 = sp.symbols('n')
n2 = sp.symbols('n',integer=True)
n3 = sp.symbols('n',odd=True)

# %%
sp.cos(n1*sp.pi),sp.cos(n2*sp.pi),sp.cos(n3*sp.pi)
# Out:
# ⎛              n    ⎞
# ⎝cos(π⋅n), (-1) , -1⎠

# %%
(sp.Rational(2,7),sp.Rational(10,55))
# Out:
# (2/7, 2/11)

# %%
[sp.N(_[ind],20) for ind in range(len(_))], [(_[ind]).evalf(10) for ind in range(len(_))]
# Out:
# ([0.28571428571428571429, 0.18181818181818181818], [0.2857142857, 0.1818181818
# ])

# %%
f=sp.Function('f')(x)

# %%
f
# Out:
# f(x)

# %%
g=sp.Lambda(x,x**7+2*x**3+sp.sin(2*x)-sp.exp(x**2))

# %%
g(x)
# Out:
#              ⎛ 2⎞
#  7      3    ⎝x ⎠
# x  + 2⋅x  - ℯ     + sin(2⋅x)

# %%
g(3),sp.N(g(3),100),g(3).evalf(100)
# Out:
# ⎛   9
# ⎝- ℯ  + sin(6) + 2241, -5862.3633430735829335828082448793718597711040826959316
#
#
# 66818642403547925826844683473021305761346914289, -5862.36334307358293358280824
#
#                                                                          ⎞
# 4879371859771104082695931666818642403547925826844683473021305761346914289⎠

# %%
sp.diff(f),sp.diff(f,x,2),sp.diff(f,x,3)
# Out:
# ⎛            2          3      ⎞
# ⎜d          d          d       ⎟
# ⎜──(f(x)), ───(f(x)), ───(f(x))⎟
# ⎜dx          2          3      ⎟
# ⎝          dx         dx       ⎠

# %%
sp.diff(g(x)),sp.diff(g(x),x,x),sp.diff(g(x),x,3)
# Out:
# ⎛                   ⎛ 2⎞                 ⎛              ⎛ 2⎞          ⎛ 2⎞
# ⎜   6      2        ⎝x ⎠                 ⎜    5      2  ⎝x ⎠          ⎝x ⎠
# ⎝7⋅x  + 6⋅x  - 2⋅x⋅ℯ     + 2⋅cos(2⋅x), 2⋅⎝21⋅x  - 2⋅x ⋅ℯ     + 6⋅x - ℯ     - 2
#
#          ⎞    ⎛               ⎛ 2⎞        ⎛ 2⎞                 ⎞⎞
#          ⎟    ⎜     4      3  ⎝x ⎠        ⎝x ⎠                 ⎟⎟
# ⋅sin(2⋅x)⎠, 2⋅⎝105⋅x  - 4⋅x ⋅ℯ     - 6⋅x⋅ℯ     - 4⋅cos(2⋅x) + 6⎠⎠

# %%
h=sp.Function('h')

# %%
sp.diff(h(x)),sp.diff(h(y)),sp.diff(h(x,y),x),sp.diff(h(x,y),y),sp.diff(h(x,y),x,y),sp.diff(h(x,y),y,x),sp.diff(h(x,y),x,2,y,3)
# Out:
# ⎛                                                 2               2
# ⎜d         d         ∂            ∂              ∂               ∂
# ⎜──(h(x)), ──(h(y)), ──(h(x, y)), ──(h(x, y)), ─────(h(x, y)), ─────(h(x, y)),
# ⎜dx        dy        ∂x           ∂y           ∂y ∂x           ∂y ∂x
# ⎝
#
#      5           ⎞
#     ∂            ⎟
#  ───────(h(x, y))⎟
#    3   2         ⎟
#  ∂y  ∂x          ⎠

# %%
sp.diff(sp.diff(h(x,y),x),y),sp.diff(sp.diff(h(x,y),y),x)
# Out:
# ⎛   2               2          ⎞
# ⎜  ∂               ∂           ⎟
# ⎜─────(h(x, y)), ─────(h(x, y))⎟
# ⎝∂y ∂x           ∂y ∂x         ⎠

# %%
h=sp.Lambda((x, y),sp.sin(x+y)*sp.exp(x/y))

# %%
h
# Out:
#           x
#           ─
#           y
# (x, y) ↦ ℯ ⋅sin(x + y)

# %%
h(1,2),h(1,2).evalf(10)
# Out:
# ⎛ 1/2                    ⎞
# ⎝ℯ   ⋅sin(3), 0.232667559⎠

# %%
sp.diff(h(x,y),y)
# Out:
#      x
#      ─               x
#      y               ─
#   x⋅ℯ ⋅sin(x + y)    y
# - ─────────────── + ℯ ⋅cos(x + y)
#           2
#          y

# %%
sp.diff(h(x,y),x,y) == sp.diff(h(x,y),y,x)
# Out:
# True

# %%
sp.diff(h(x,y),y,x)
# Out:
#                                                                         x
#                                                                         ─
# ⎛  x⋅cos(x + y)   x⋅sin(x + y)                cos(x + y)   sin(x + y)⎞  y
# ⎜- ──────────── - ──────────── - sin(x + y) + ────────── - ──────────⎟⋅ℯ
# ⎜        2              3                         y             2    ⎟
# ⎝       y              y                                       y     ⎠

# %%
sp.diff(h(x,y),x,y)
# Out:
#                                                                         x
#                                                                         ─
# ⎛  x⋅cos(x + y)   x⋅sin(x + y)                cos(x + y)   sin(x + y)⎞  y
# ⎜- ──────────── - ──────────── - sin(x + y) + ────────── - ──────────⎟⋅ℯ
# ⎜        2              3                         y             2    ⎟
# ⎝       y              y                                       y     ⎠

# %%
wielomian = x**3+2*x**2-x+2

# %%
wielomian
# Out:
#  3      2
# x  + 2⋅x  - x + 2

# %%
type(wielomian)
# Out:
# sympy.core.add.Add

# %%
wielomian.args
# Out:
# ⎛    3         2⎞
# ⎝2, x , -x, 2⋅x ⎠

# %%
[wielomian.args[licz] for licz in range(len(wielomian.args))]
# Out:
# ⎡    3         2⎤
# ⎣2, x , -x, 2⋅x ⎦

# %%
[wielomian.args[licz].args for licz in range(len(wielomian.args))]
# Out:
# ⎡                     ⎛    2⎞⎤
# ⎣(), (x, 3), (-1, x), ⎝2, x ⎠⎦

# %%
wielomian.args[3].args[1].args[1]
# Out:
# 2

# %%
wielomian1 = x**2-5*x+6

# %%
wielomian1
# Out:
#  2
# x  - 5⋅x + 6

# %%
sp.simplify(wielomian1)
# Out:
#  2
# x  - 5⋅x + 6

# %%
sp.factor(wielomian1)
# Out:
# (x - 3)⋅(x - 2)

# %%
tryg=sp.sin(x)*sp.cos(x)*(sp.exp(x)*sp.exp(3*x))

# %%
tryg
# Out:
#  4⋅x
# ℯ   ⋅sin(x)⋅cos(x)

# %%
sp.simplify(tryg)
# Out:
#  4⋅x
# ℯ   ⋅sin(2⋅x)
# ─────────────
#       2

# %%
expr = (x**3 + x**2 - x - 1)/(x**2 + 2 * x + 1)

# %%
expr,expr.simplify()
# Out:
# ⎛ 3    2               ⎞
# ⎜x  + x  - x - 1       ⎟
# ⎜───────────────, x - 1⎟
# ⎜   2                  ⎟
# ⎝  x  + 2⋅x + 1        ⎠

# %%
tryg = sp.cos(x)/(1-sp.sin(x)**2)

# %%
tryg,tryg.simplify()
# Out:
# ⎛   cos(x)      1   ⎞
# ⎜───────────, ──────⎟
# ⎜       2     cos(x)⎟
# ⎝1 - sin (x)        ⎠

# %%
sp.apart(1/(x**8-x**6))
# Out:
#       1           1       1    1    1
# - ───────── + ───────── - ── - ── - ──
#   2⋅(x + 1)   2⋅(x - 1)    2    4    6
#                           x    x    x
